# %%
from datetime import datetime
from app.download_and_fill_historical_data import download_and_fill_db
from app.scrape_and_fill_company_stats import scrape_and_fill_db

# %%
download_and_fill_db(end_date=datetime.now())

# %%
scrape_and_fill_db()
# Out:
# Connected to the PostgreSQL database stocks
# 1 companyarecord inserted successfully into historical table
# 1 companyaaprecord inserted successfully into historical table
# 1 companyaaplrecord inserted successfully into historical table
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10564\281289702.py in <module>
# ----> 1 scrape_and_fill_db()
#
# D:\dev\playground\python\stock_analysis\app\scrape_and_fill_company_stats.py in scrape_and_fill_db()
#     131     for symbol in symbols:
#     132
# --> 133         scrape_and_fill_company_stats(connection, cursor, symbol)
#     134
#     135     cursor.close()
#
# D:\dev\playground\python\stock_analysis\app\scrape_and_fill_company_stats.py in scrape_and_fill_company_stats(connection, cursor, symbol)
#     105
#     106     try:
# --> 107         data_dictionary = scrape_summary(symbol)
# ...

# %%
from db.db_tools import connect_db
import pandas as pd

table_name = "all_historical_data"
company_symbol = "'A'"

connection = connect_db()
res = pd.read_sql(f'select * from {table_name} where symbol={company_symbol} order by date DESC', connection)
# Out:
# Connected to the PostgreSQL database stocks

# %%
res
# Out:
#                                     id        date      open      high  \
# 0     A_2023-02-08                      2023-02-08  153.6400  155.1700
# 1     A_2023-02-07                      2023-02-07  151.4900  154.9600
# 2     A_2023-02-06                      2023-02-06  152.7300  154.4000
# 3     A_2023-02-03                      2023-02-03  153.1700  155.4200
# 4     A_2023-02-02                      2023-02-02  156.6600  157.3100
# ...                                ...         ...       ...       ...
# 5808  A_2000-01-07                      2000-01-07   42.2479   47.1656
# 5809  A_2000-01-06                      2000-01-06   44.0808   44.3491
# 5810  A_2000-01-05                      2000-01-05   47.3891   47.5680
# 5811  A_2000-01-04                      2000-01-04   48.7303   49.2668
# 5812  A_2000-01-03                      2000-01-03   56.3305   56.4646
#
#            low     close   volume  symbol  company_id
# 0     153.2300  154.4200  1073500  A                1
# ...

# %%
table_name = "all_company_stats"
company_symbol = "'A'"

connection = connect_db()
res = pd.read_sql(f'select * from {table_name} where symbol={company_symbol} order by date DESC', connection)
# Out:
# Connected to the PostgreSQL database stocks

# %%
res
# Out:
#                                  id        date  symbol   price  price_change  \
# 0  A_2023-02-09                      2023-02-09  A       154.42         -0.09
# 1  A_2023-02-03                      2023-02-03  A       155.50          0.05
#
#    previous_close    open                       bid                       ask  \
# 0          154.51  153.64  128.00 x 900              156.00 x 900
# 1          155.45  156.66  0.00 x 800                0.00 x 800
#
#                  days_range  ... quarterly_earnings_growth  total_cash  \
# 0  153.23 - 155.17           ...                  -16.70      1.05B
# 1  154.77 - 157.31           ...                  -16.70      1.05B
#
#    total_cash_per_share total_debt  total_debt_over_equity  current_ratio  \
# 0                  3.56   2.92B                      55.08           2.03
# 1                  3.56   2.92B                      55.08           2.03
#
#    book_value_per_share operating_cash_flow levered_free_cash_flow company_id
# ...
